# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from IPython.core.pylabtools import figsize
from IPython.html.widgets import interact, interactive, fixed
from IPython.html import widgets
from IPython.display import clear_output, display, HTML
import pandas as pd
from pandas.tools.plotting import *
import seaborn
from os import listdir
# %load_ext autoreload
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))

# %%
# %aimport funcs

# %%
# %autoreload 1

# %% [markdown]
# #Clasification

# %%
dfc=funcs.Folder_Classification_Report('Cres')
# Out:
# Reading 32 files in Cres
# 0
#  i96h24n0.2d0.01c4000.res 0.908082305626
# 1
#  i96h48n0.02d0.1c2000.res 0.939144322275
# 2
#  i96h48n0.02d0.01c2000.res 0.929582309133
# 3
#  i96h12h12n0.2d0.01c3000.res 0.916655636415
# 4
#  i96h12h12n0.02d0.2c3000.res 0.94844451544
# 5
#  i96h24h12n0.2d0.1c3000.res 0.923462766733
# 6
#  i96h12h12n0.35d0.1c3000.res 0.900653629966
# 7
#  i96h24h12n0.02d0.1c3000.res 0.951411164141
# 8
#  i96h48n0.2d0.1c2000.res 0.907774076211
# 9
#  i96h24n0.02d0.01c4000.res 0.929788608461
# 10
#  i96h24h12n0.02d0.01c3000.res 0.936750582879
# 11
#  i96h12n0.2d0.1c3000.res 0.894090244762
# 12
#  i96h24h12n0.35d0.1c3000.res 0.909551506501
# 13
#  i96h12h12n0.2d0.1c2000.res 0.921911786009
# 14
#  i96h24n0.2d0.1c4000.res 0.919599703787
# 15
#  i96h24n0.35d0.01c4000.res 0.903189467974
# 16
#  i96h12n0.02d0.01c5000.res 0.931376235223
# 17
#  i96h48n0.35d0.01c2000.res 0.909812722732
# 18
#  i96h12h12n0.35d0.01c3000.res 0.899927653303
# 19
# ...

# %%
seaborn.factorplot('d','Accuracy','n',dfc,kind='box',aspect=3)

# %%
dfc.sort('Accuracy')
# Out:
#     Accuracy                            File        Layers       TPE  \
# 11  0.894090         i96h12n0.2d0.1c3000.res          [12]  0.821415
# 28  0.899508       i96h12n0.35d0.01c3000.res          [12]  0.858137
# 18  0.899928    i96h12h12n0.35d0.01c3000.res      [12, 12]  0.826826
# 6   0.900654     i96h12h12n0.35d0.1c3000.res      [12, 12]  0.848860
# 15  0.903189       i96h24n0.35d0.01c4000.res          [24]  0.885195
# 8   0.907774         i96h48n0.2d0.1c2000.res          [48]  0.904136
# 0   0.908082        i96h24n0.2d0.01c4000.res          [24]  0.927329
# 12  0.909552     i96h24h12n0.35d0.1c3000.res      [24, 12]  0.884036
# 17  0.909813       i96h48n0.35d0.01c2000.res          [48]  0.905682
# 29  0.910316     i96h24h12n0.2d0.01c3000.res      [24, 12]  0.909934
# 19  0.915015        i96h48n0.2d0.01c2000.res          [48]  0.938925
# 27  0.915594        i96h12n0.35d0.1c5000.res          [12]  0.894086
# 24  0.916130    i96h24h12n0.35d0.01c3000.res      [24, 12]  0.897565
# ...

# %%
funcs.Full_Clasification_Report('Cres/i96h24h12n0.02d0.1c3000.res')

# %%
dfr=funcs.Folder_Regression_Report('AZres')
# Out:
# Reading 23 files in AZres
# 0
#  i96o2h12n0.02d0.001c20.res 0.0161156019938 0.00330029299554
# 1
#  i96o2h24n0.2d0.01c1.res 0.431297720814 0.100084073753
# 2
#  i96o2h12n0.2d0.001c1.res 0.0472345902455 0.00649141062851
# 3
#  i96o2h24n0.02d0.001c500.res 0.0090125914575 0.00156421719802
# 4
#  i96o2h24n0.02d0.01c25.res 0.0111272826513 0.00235476516179
# 5
#  i96o2h24h12n0.2d0.1c2.res 0.0274962956668 0.00468835765793
# 6
#  i96o2h12n0.002d0.1c50.res 0.0353989360635 0.00771992617875
# 7
#  i96o2h24h12n0.02d0.01c3.5.res 0.0133907902431 0.00222097321333
# 8
#  i96o2h24n0.002d0.001c300.res 0.0102388676932 0.00192579590311
# 9
#  i96o2h24n0.2d0.001c1.res 0.558636733298 0.0861208763513
# 10
#  i96o2h12n0.02d0.01c10.res 0.0172896379811 0.00365530112906
# 11
#  i96o2h24h12n0.2d0.001c2.res 0.0146440815736 0.00189023670085
# 12
#  i96o2h24n0.2d0.1c1.res 0.375057434774 0.088600596029
# 13
#  i96o2h24h12n0.002d0.001c500.res 0.00739962332444 0.00118678316234
# 14
# ...

# %%
seaborn.factorplot('d','SDZ','n',dfr[dfr['n']!=0.2],kind='box',aspect=3)

# %%
dfr.sort(['SDA','SDZ'])
# Out:
#                                File    Layers       SDA       SDZ      d  \
# 13  i96o2h24h12n0.002d0.001c500.res  [24, 12]  0.007400  0.001187  0.001
# 18   i96o2h24h12n0.002d0.01c500.res  [24, 12]  0.007679  0.001444  0.010
# 3       i96o2h24n0.02d0.001c500.res      [24]  0.009013  0.001564  0.001
# 8      i96o2h24n0.002d0.001c300.res      [24]  0.010239  0.001926  0.001
# 4         i96o2h24n0.02d0.01c25.res      [24]  0.011127  0.002355  0.010
# 19     i96o2h24h12n0.02d0.001c5.res  [24, 12]  0.011383  0.001682  0.001
# 7     i96o2h24h12n0.02d0.01c3.5.res  [24, 12]  0.013391  0.002221  0.010
# 11      i96o2h24h12n0.2d0.001c2.res  [24, 12]  0.014644  0.001890  0.001
# 0        i96o2h12n0.02d0.001c20.res      [12]  0.016116  0.003300  0.001
# 10        i96o2h12n0.02d0.01c10.res      [12]  0.017290  0.003655  0.010
# 21       i96o2h24n0.002d0.01c9t.res      [24]  0.020035  0.005013  0.010
# 5         i96o2h24h12n0.2d0.1c2.res  [24, 12]  0.027496  0.004688  0.100
# ...

# %%
funcs.plot_reg('AZres/i96o2h24h12n0.002d0.001c500.res')
